# %%
import logging

# create a logger for module 1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

# create a logger fmor module2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# configure logging settings
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%M-%d %H:%M:%S'
)

# %%
# log messages with different loggers
logger1.debug("This is debug message for modeul1")
logger2.warning("This is a warning message for module2")
logger2.error("This is an error message")
# Out:
# 2026-56-23 13:56:27 - module1 - DEBUG - This is debug message for modeul1
# 2026-56-23 13:56:27 - module2 - WARNING - This is a warning message for module2
# 2026-56-23 13:56:27 - module2 - ERROR - This is an error message
