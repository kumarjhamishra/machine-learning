# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi

print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np 
np.array([1,2,4,5])
# Out:
# array([1, 2, 4, 5])

# %%
# importing all the functions from a library
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition

addition(4,5)

# to make the package an importable module we need to make a __init__.py -> that's compulsory
# also to improt a folder as package it should be in the same directory as the file which is importing it
# Out:
# 9

# %%
from package import maths

maths.addition(2,3)
# Out:
# 5
