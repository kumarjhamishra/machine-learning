# %%
import array
arr = array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random

for i in range(0, 5):
    print(random.randint(1,10))
    print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 1
# banana
# 1
# banana
# 3
# cherry
# 4
# banana
# 1
# banana

# %%
# file and directory access

import os
# to find the current working directory
print(os.getcwd())
# Out:
# d:\machine_learning\8_importing_creating_modules_and_packages

# %%
# to make a directory
os.mkdir('test_dir')

# %%
# to make a new file


# os.O_CREAT → create if it doesn't exist
# os.O_WRONLY → open for writing
# fd = os.open("test1.py", os.O_CREAT | os.O_WRONLY)
fd = os.open("test1.py", os.O_CREAT | os.O_WRONLY)

# Close file descriptor
os.close(fd)

# %%
# high level operations on files and collection of files

import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# data serialization

import json
data = {'name': 'Satyam', 'age': 20}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Satyam", "age": 20}
# <class 'str'>
# {'name': 'Satyam', 'age': 20}
# <class 'dict'>

# %%
import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Satyam', 20])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Satyam', '20']

# %%
from datetime import datetime, timedelta

now = datetime.now()
print(now)

# time of yesterday
yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2025-10-03 00:57:00.073023
# 2025-10-02 00:57:00.073023

# %%
import time
print(time.time())
time.sleep(2) # delay for 2 seconds
print(time.time())
# Out:
# 1759433306.6711938
# 1759433308.6723075

# %%
# regular expression

import re

# digits
pattern = '\d+' 
text = 'There are 123 apples'
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18172\1034024765.py:6: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d+'
