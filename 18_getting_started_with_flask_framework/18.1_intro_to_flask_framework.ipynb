# %% [markdown]
# ## Flask Framework
#
# ### WSGI -> Web Server Gateway Interface
# ### Jinja 2 -> Template Engine
#
# #### Flask - web framwework created with python
# protocol between deployed web server and web app
#
# Jinja 2 -> combines web templates with data source
